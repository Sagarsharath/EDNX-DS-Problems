# %%
import csv

#complete file-path
inputFilePath = "dc-wikia-data.csv"

totalAppearances = {}
livingDict = {}

with open(inputFilePath) as csvFile:
    reader = csv.reader(csvFile)
    headers = next(reader)
    for row in reader:
        name = row[1].split("(")[0].rstrip()
        living = row[9]
        world = row[1][row[1].find("(") +1: row[1].find(")")]
        try:
            appear = int(row[10])
        except:
            continue
        if living == "Living Characters":
            if world not in livingDict:
                livingDict[world] = []
            if world not in totalAppearances:
                totalAppearances[world] = 0
                
            livingDict[world].append(name)
            totalAppearances[world] += int(appear)

print(livingDict)
print('-----------')
print(totalAppearances)
# Out:
# {'Bruce Wayne': ['Batman'], 'Clark Kent': ['Superman'], 'Hal Jordan': ['Green Lantern'], 'New Earth': ['James Gordon', 'Richard Grayson', 'Timothy Drake', 'Dinah Laurel Lance', 'Barbara Gordon', 'Jason Garrick', 'Lois Lane', 'Alfred Pennyworth', 'Carter Hall', 'Kyle Rayner', 'Raymond Palmer', 'Alexander Luthor', 'Roy Harper', 'Ted Grant', 'Garfield Logan', 'Guy Gardner', 'Victor Stone', 'Kon-El', 'James Olsen', 'John Stewart', 'Joker', 'Franklin Rock', 'Rex Mason', 'Zatanna Zatara', 'Aztar', 'Michael Jon Carter', 'Cassandra Sandsmark', 'Harvey Bullock', 'Rachel Roth', 'Helena Bertinelli', 'Nathaniel Adam', 'Ronald Raymond', 'Red Tornado', 'John Constantine', 'Lobo', 'Perry White', 'John Henry Irons', 'Jefferson Pierce', 'Slade Wilson', 'Phantom Stranger', 'Beatriz da Costa', 'William Batson', 'Carol Ferris', 'Clifford Steele', 'Etrigan', 'Jennifer-Lynn Hayden', 'Swamp Thing', 'Renee Montoya', 'Harvey Dent', 'Courtney Whitmore', 'Michael Holt', 'Kilowog', 'Kara Zor-El', 'Rex Tyler', 'Pamela Isley', 'Pieter Cross', 'Jonathan L. Thunder', 'Mari McCabe', 'Scott Free', 'Martha Clark', 'Oswald Cobblepot', 'Tatsu Yamashiro', 'Lawrence Trainor', 'Albert Rothstein', 'Brion Markov', 'Sanderson Hawkins', 'Thaal Sinestro', 'Cassandra Cain', 'Jason Todd', 'Hippolyta', 'Joseph Wilson', 'Bernhard Baker', 'Jesse Chambers', 'Floyd Lawton', 'Mera', 'Tora Olafsdotter', 'George Harkness', 'Amanda Waller', 'Jonathan Crane', 'Leonard Snart', 'Shiera Sanders', 'Maxwell Lord IV', 'Jeb Stuart', 'Niles Caulder', 'Samuel Bradley', 'Richard Tyler', 'Todd Rice', 'Yz', 'Wolfgang Winks', 'Stephanie Brown', 'Raymond Terrill', 'Adam Blake', 'Kimiyo Hoshi', 'Jack Ryder', 'Vandar Adg', 'Justin Arthur', 'Max Mercury', 'Abigail Arcane', 'Margaret Sawyer', 'Waylon Jones', 'Gorilla Grodd', 'Adam Strange', 'Patrick Dugan', 'Daniel Cassidy', 'James Harper Clone', 'Thomas Kalmaku', 'Gabrielle Doe', 'Henry Hall', 'Connor Hawke', 'Linda Park', 'Edward Nashton', 'Arisia Rrab', 'Robert Crane', 'Joan Williams', 'William Magnus', 'Mary Batson', 'Oberon', 'Rita Farr', 'Jason Rusch', 'Mercury', 'Jaime Reyes', 'Platinum', 'Andre Chavard', 'Vril Dox II', 'Roy Raymond, Sr.', 'Uncle Sam', 'Iron', 'Lead', 'Lucas Carr', 'Hartley Rathaway', 'Lana Lang', 'Rose Wilson', 'DeSaad', 'Bane', 'Salakk', 'Tin', 'Eve Eden', 'Harleen Quinzel', 'Benjamin Turner', 'Mark Mardon', 'Teth-Adam', 'Catherine Grant', 'Jason Blood', 'Gold', 'Victor Fries', 'Lester Davis', 'Artemis of Bana-Mighdall', 'Alanna Strange', 'Nuidis Vulko', 'Steven Dayton', 'Solis', 'Alfred Twidgett', 'Tubby Watts', 'Cynthia Reynolds', 'Victoria Vale', 'Lucius Fox', 'Ganthet', 'Barbara Ann Minerva', 'Rory Regan', 'Eclipso', 'Mick Rory', 'Kyle Morgan', 'Matthew Ryan', 'Robert Langstrom', 'Sargent Steel', 'Victory', 'Walter Haley', 'Ares', 'Rip Carter', 'Emil Hamilton', 'Richard Swift', 'Frederick Freeman', 'Katar Hol', 'Richard Occult', 'Dawn Granger', 'Linda Danvers', 'Dubbilex', 'Antonia Monetti', 'Jack Knight', 'Skeets', 'Nimue Inwudu', 'Khaji Da', 'Elizabeth Lawrence', 'Pallas Athena', 'Evan McCulloch', 'Strata', 'Zeus', 'Holly Robinson', 'Jason Woodrue', 'Leslie Thompkins', 'June Moone', 'Mia Dearden', 'Krypto', 'Ohiyesa I', 'Zauriel', 'Leonid Kovar', 'Thomas Blake', 'Emily Briggs', 'Thomas Tresser', 'Hans von Hammer', 'William Polk', 'Bruce Gordon', 'Sugar Plumm', 'Jervis Tetch', 'Enya Wazzo', 'Werner Vertigo', 'Sapphire Stagg', 'Zinda Blake', 'Cecil Wilson', 'Aphrodite', 'Jade Nguyen', 'Rip Hunter', 'Wing How', 'Vril Dox I', 'Grace Choi', 'Natasha Irons', 'Katherine Spencer', 'Lorraine Reilly', 'Noah Kuttler', 'Despero', 'Jan Haasan', 'Tef\\u00e9 Holland', 'Bizarro', 'Henry Henshaw', 'Charles Dickles', 'Maxine Hunkel', 'Wade Eiling', 'Black Manta', 'Felix Faust', 'Soranik Natu', 'Anissa Pierce', 'Henry King, Jr.', 'Orm Marius', 'Citizen Abra', 'Merlin', 'Danette Reilly', 'Ronald Troupe', 'Hermes', 'Timothy Hunter', 'Taghurrhu', 'Sandra Wu-San', 'William Zard', 'Philippus', 'David Clinton', 'Bobo T. Chimpanzee', 'Mister Bo ...
# -----------
# {'Bruce Wayne': 3093, 'Clark Kent': 2496, 'Hal Jordan': 1565, 'New Earth': 106607, 'Diana Prince': 1231, 'Arthur Curry': 1121, 'Barry Allen': 1028, 'GenderTes': 1028, 'Earth-Two': 659, 'Pocket Universe': 206, 'Pre-Zero Hour': 342, 'Dakotaverse': 603, 'Team Titans': 103, 'Earth-X': 79, 'Santa Clau': 32, 'Bandage Peopl': 23, 'Earth-One': 141, 'Prime Earth': 44, 'Roman God': 13, 'Female Furies': 11, 'DC One Million': 13, 'Virus': 9, 'Vertigo Universe': 8, 'Post-Zero Hour': 11, 'Roman Goddess': 5, 'S.H.A.D.E.': 4, 'Earth-3': 4, 'The Elite': 4, 'Exterminator Robot': 4, 'Green Lantern Animated Series': 3, 'Animal Man': 3, 'Some Years Later': 2, 'Imposter': 2, 'clone': 1, 'O.G.R.E.': 2, 'Earth-Four': 1, 'robot': 1, 'Oliver Queen': 1}
